# %%
## test print

print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = range(100)

y = [i**2 for i in x]

# %%
x = pd.Series(x)

# %%
y = pd.Series(y)

# %%
x.describe(
)
# Out:
# count    100.000000
# mean      49.500000
# std       29.011492
# min        0.000000
# 25%       24.750000
# 50%       49.500000
# 75%       74.250000
# max       99.000000
# dtype: float64

# %%
y.describe()
# Out:
# count     100.000000
# mean     3283.500000
# std      2968.174804
# min         0.000000
# 25%       612.750000
# 50%      2450.500000
# 75%      5513.250000
# max      9801.000000
# dtype: float64

# %%
plt.plot(x, y)
